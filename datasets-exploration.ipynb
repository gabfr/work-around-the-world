# %% [markdown]
# # Data Sources/sets exploration
#
# First of all we will load/create the configurations/clients:

# %%
# !pip install configparser
# !pip install requests
# Out:
# Requirement already satisfied: configparser in /opt/conda/lib/python3.7/site-packages (3.8.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests) (2.8)

# %%
from pyspark.sql import SparkSession
import configparser

config = configparser.ConfigParser()
config.read_file(open('dc.cfg'))

landingJobsApiKey = config.get('LANDINGJOBS', 'API_KEY')

spark = SparkSession.builder.appName("Truck Data Wrangler").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0efa937a9e03:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Truck Data Wrangler</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Data Sources
#
# Down below we will check each data sources (from APIs to csv/json files)
#
# ### Dice US Jobs
#
# The source: https://data.world/promptcloud/us-jobs-on-dice-com

# %%
csv_file = 'datasets/Dice_US_jobs.csv'

dice_us_jobs_df = spark.read.csv(csv_file, header=True)

dice_us_jobs_df.limit(20).toPandas()
# Out:
#    country_code  date_added             job_board  \
# 0            US  11/11/2016  https://www.dice.com
# 1            US  11/11/2016  https://www.dice.com
# 2            US  11/11/2016  https://www.dice.com
# 3            US  11/12/2016  https://www.dice.com
# 4            US  11/11/2016  https://www.dice.com
# 5            US  11/11/2016  https://www.dice.com
# 6            US  11/11/2016  https://www.dice.com
# 7            US  11/11/2016  https://www.dice.com
# 8            US  11/11/2016  https://www.dice.com
# 9            US  11/12/2016  https://www.dice.com
# 10           US  11/12/2016  https://www.dice.com
# 11           US  11/11/2016  https://www.dice.com
# 12           US  11/11/2016  https://www.dice.com
# 13           US  11/12/2016  https://www.dice.com
# 14           US  11/12/2016  https://www.dice.com
# 15           US  11/12/2016  https://www.dice.com
# 16           US  11/11/2016  https://www.dice.com
# 17           US  11/11/2016  https://www.dice.com
# 18           US  11/12/2016  https://www.dice.com
# 19           US  11/12/2016  https://www.dice.com
#
#                                       job_description  \
# 0   Minimum Required Skills:EDI, TrustedLink, AS2,...
# 1   Informatica��/ ETL DeveloperSt, Petersburg, FL...
# 2   pmayekar@kanandcorp.com 512-697-8897Sunnyvale ...
# 3   "This nationally recognized Microsoft Gold Par...
# 4   Minimum Required Skills:C#, ASP.NET, SQL, Java...
# 5   Minimum Required Skills:Machine Learning, Java...
# 6   Hatstand, a global financial consultancy, is s...
# 7   Linux System Administrator opportunity- with i...
# 8   Varite is looking for Senior Commission Analys...
# 9   Tranzeal is an industry leading global Busines...
# 10  Duties:Migrating SQL Server data warehouse to ...
# 11  Hi, ������������������������������������������...
# 12  Minimum Required Skills:C#, ASP.NET, JavaScrip...
# 13  Title: Field Service Technician-   Location: S...
# 14  If you are excited by the opportunity to desig...
# 15  **Locals to San Francisco Bay Area preferred**...
# 16  ***SUBMISSIONS DUE: Monday November 14th @ 10:...
# 17  Are you looking for a career trajectory that f...
# 18  Please apply quickly at raj(at)zealtechus.com ...
# 19  Live IT Up at CiberAt Ciber, we believe the mo...
#
#                                          job_title  \
# 0                                      EDI Analyst
# 1                        Informatica ETL Developer
# 2                                Angular developer
# 3                              including templates
# 4                               Software Developer
# 5                        Machine Learning Engineer
# 6                              Core Java Developer
# 7                       Linux System Administrator
# 8                               Commission Analyst
# 9                                 Drupal Developer
# 10      SQL/SSIS Developer (AWS Migration Project)
# 11  PMO (for Purchase to Pay Support) OR Purchaser
# 12                           Senior .NET Developer
# 13                  Field Service Technician II US
# 14                   Software Development Engineer
# 15          Business Operations /Financial Analyst
# 16                      Personalization Specialist
# 17  SAP Ariba Consultant (Supply Chain Capability)
# 18                               MONGOdb and  JAVA
# 19                               Software Engineer
#
#                                              job_type  \
# 0                      Full Time, Full-time, Employee
# 1                                Full Time, Full Time
# 2   Full Time, Contract Corp-To-Corp, Contract Ind...
# 3                                          work plans
# 4                      Full Time, Full-time, Employee
# 5                      Full Time, Full-time, Employee
# 6                        Full Time, C2H W2, FTE - C2H
# 7                                           Full Time
# 8   Full Time, Contract Independent, Contract W2, ...
# 9   Contract Corp-To-Corp, Contract Independent, C...
# 10  Contract Corp-To-Corp, Contract Independent, C...
# 11  Full Time, Contract Corp-To-Corp, Contract Ind...
# 12                     Full Time, Full-time, Employee
# 13  Contract Independent, Contract W2, C2H Indepen...
# 14                                          Full Time
# 15  Contract Corp-To-Corp, Contract Independent, C...
# 16                                        Contract W2
# 17                               Full Time, Permanent
# 18  Contract Corp-To-Corp, Contract Independent, C...
# 19                                          Full Time
#
#                                              location  \
# 0                                        Stamford, CT
# 1                                   St Petersburg, FL
# 2                                       Sunnyvale, CA
# 3    methodologies*Enhances practice's and organiz...
# 4                                        Stamford, CT
# 5                                         Toronto, ON
# 6                                        Stamford, CT
# 7                                        Stamford, CT
# 8                                       Sunnyvale, CA
# 9                                       Sunnyvale, CA
# 10                                   Santa Monica, CA
# 11                                      Sunnyvale, CA
# 12                                       Stamford, CT
# 13                                        Seattle, WA
# 14                                        Seattle, WA
# 15                                      Sunnyvale, CA
# 16        55 Bloor St W, Toronto, Ontario, Canada, ON
# 17                                    Tallahassee, FL
# 18                                      Sunnyvale, CA
# 19                                          Tampa, FL
#
#                                          organization  \
# 0                                         CyberCoders
# 1                                          TrustMinds
# 2                                 K Anand Corporation
# 3    customer and staff issues independently and w...
# 4                                         CyberCoders
# 5                                         CyberCoders
# 6                                         Hatstand US
# 7                                  Landover Assocates
# 8                                              Varite
# 9                                            Tranzeal
# 10                                             Tentek
# 11                          Brainhunter Companies LLC
# 12                                        CyberCoders
# 13                                   Matrix Resources
# 14                                             Amazon
# 15                                          Opal Soft
# 16                                         TEKsystems
# 17                                           Deloitte
# 18                                           ZealTech
# 19                                              Ciber
#
#                                              page_url  \
# 0   https://www.dice.com/jobs/detail/EDI-Analyst-%...
# 1   https://www.dice.com/jobs/detail/Informatica-E...
# 2   https://www.dice.com/jobs/detail/Angular-devel...
# 3        analyze processes and recommend improvements
# 4   https://www.dice.com/jobs/detail/Software-Deve...
# 5   https://www.dice.com/jobs/detail/Machine-Learn...
# 6   https://www.dice.com/jobs/detail/Core-Java-Dev...
# 7   https://www.dice.com/jobs/detail/Linux-System-...
# 8   https://www.dice.com/jobs/detail/Commission-An...
# 9   https://www.dice.com/jobs/detail/Drupal-Develo...
# 10  https://www.dice.com/jobs/detail/SQL%26%2347SS...
# 11  https://www.dice.com/jobs/detail/PMO-%28for-Pu...
# 12  https://www.dice.com/jobs/detail/Senior-.NET-D...
# 13  https://www.dice.com/jobs/detail/Field-Service...
# 14  https://www.dice.com/jobs/detail/Software-Deve...
# 15  https://www.dice.com/jobs/detail/Business-Oper...
# 16  https://www.dice.com/jobs/detail/Personalizati...
# 17  https://www.dice.com/jobs/detail/SAP-Ariba-Con...
# 18  https://www.dice.com/jobs/detail/MONGOdb-and--...
# 19  https://www.dice.com/jobs/detail/Software-Engi...
#
#                                          phone_number  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3    particularly when a SME is required beyond th...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                                salary  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3    complex projectsBusiness Growth & Development...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                                                sector
# 0   EDI, TrustedLink, AS2, VAN - EDI, TrustedLink,...
# 1   ETL Informatica B2B Data Exchange Netezza Orac...
# 2                                             Angular
# 3                                 marketing standards
# 4   C#, ASP.NET, SQL, JavaScript, MVC - C#, ASP.NE...
# 5   Machine Learning, Java/ Scala, SPARK, Predicti...
# 6   Java, Linux/Unix, SDLC; Multi-Threaded or Conc...
# 7                          Linux System Administrator
# 8   Commission Analyst, Sales commission analyst, ...
# 9   strong experience in Drupal application develo...
# 10                          SSIS, AWS, Scripting Tool
# 11  Purchase to Pay Support, PMO, Retail IS&T, sup...
# 12  C#, ASP.NET, JavaScript, Content Management Sy...
# 13  Hardware, Laptop, Networking, Peripherals, Pri...
# 14  C++, Development, Ecommerce, Java, Management,...
# 15                  BI, ad hoc reports, data analysis
# 16                         Personalization Specialist
# 17  Ariba, Consulting, CRM, Development, Excel, HT...
# 18                                       Mongodb java
# 19  QUALIFICATIONS: * Experience working with Sale...

# %% [markdown]
# ### Dice US Jobs [2]
#
# Source: https://www.kaggle.com/PromptCloudHQ/us-technology-jobs-on-dicecom

# %%
csv_file = 'datasets/promptcloud-us-jobs-on-dice-com/data/dice_com_job_us_sample.csv'

dice_us_jobs_df = spark.read.csv(csv_file, header=True)

dice_us_jobs_df.limit(20).toPandas()
# Out:
#                                         advertiserurl  \
# 0   https://www.dice.com/jobs/detail/AUTOMATION-TE...
# 1   https://www.dice.com/jobs/detail/Information-S...
# 2   https://www.dice.com/jobs/detail/Business-Solu...
# 3   https://www.dice.com/jobs/detail/Java-Develope...
# 4   https://www.dice.com/jobs/detail/DevOps-Engine...
# 5   https://www.dice.com/jobs/detail/SAP-FICO-Arch...
# 6   https://www.dice.com/jobs/detail/Network-Engin...
# 7   https://www.dice.com/jobs/detail/Sr.-Web-Appli...
# 8   https://www.dice.com/jobs/detail/Front-End-Dev...
# 9   https://www.dice.com/jobs/detail/Application-S...
# 10  https://www.dice.com/jobs/detail/OpenStack-Eng...
# 11  https://www.dice.com/jobs/detail/9001-Data-Sec...
# 12  https://www.dice.com/jobs/detail/Software-Engi...
# 13  https://www.dice.com/jobs/detail/Sales-Enginee...
# 14  https://www.dice.com/jobs/detail/Project-Manag...
# 15  https://www.dice.com/jobs/detail/Windows-Syste...
# 16  https://www.dice.com/jobs/detail/Test-Lead-%25...
# 17  https://www.dice.com/jobs/detail/Principal-App...
# 18  https://www.dice.com/jobs/detail/Messaging-Adm...
# 19  https://www.dice.com/jobs/detail/Java-Architec...
#
#                                 company  \
# 0     Digital Intelligence Systems, LLC
# 1     University of Chicago/IT Services
# 2                  Galaxy Systems, Inc.
# 3                         TransTech LLC
# 4                      Matrix Resources
# 5                     Yash Technologies
# 6                                Noble1
# 7               Bluebeam Software, Inc.
# 8                             Genesis10
# 9       VanderHouwen & Associates, Inc.
# 10                        Maxonic, Inc.
# 11    CSI (Consultant Specialists Inc.)
# 12      VanderHouwen & Associates, Inc.
# 13                            Genesis10
# 14      VanderHouwen & Associates, Inc.
# 15        Eastridge Workforce Solutions
# 16                            Collabera
# 17      VanderHouwen & Associates, Inc.
# 18                            Genesis10
# 19  Fahrenheit IT Staffing & Consulting
#
#                              employmenttype_jobstatus  \
# 0   C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...
# 1                                           Full Time
# 2                                           Full Time
# 3                                           Full Time
# 4                                           Full Time
# 5                                Full Time, Permanant
# 6                              Full Time, Direct Hire
# 7                                Full Time, Full Time
# 8                         Full Time, Direct Placement
# 9                            C2H W2, Contract to hire
# 10                                          Full Time
# 11  Full Time, Contract Corp-To-Corp, Contract Ind...
# 12                               Full Time, Full time
# 13                        Full Time, Direct Placement
# 14                              Contract W2, Contract
# 15                        Full Time, contract-to-hire
# 16                                        Contract W2
# 17                               Full Time, Full time
# 18                        Full Time, Direct Placement
# 19                             Full Time, Direct Hire
#
#                                        jobdescription  \
# 0   Looking for Selenium engineers...must have sol...
# 1   The University of Chicago has a rapidly growin...
# 2   GalaxE.SolutionsEvery day, our solutions affec...
# 3   Java DeveloperFull-time/direct-hireBolingbrook...
# 4   Midtown based high tech firm has an immediate ...
# 5   We are looking for a Senior SAP FICO Architect...
# 6   Network Engineer Job Description A Network Eng...
# 7   Bluebeam is looking for talented sr. web devel...
# 8   This is a fulltime position for a Javascript d...
# 9   SummaryOur client is the leading provider of o...
# 10  JOB DESCRIPTION:As a senior member of the team...
# 11  Must have skills: UNIX, IAM (Identity Access M...
# 12  VanderHouwen has more jobs you may like!  Find...
# 13  Genesis10 is currently seeking a Sales Enginee...
# 14  VanderHouwen has more jobs you may like! Find ...
# 15  "Windows Systems Administrator The Windows Sys...
# 16  Location Atlanta, GAJob Title Test Lead / Mana...
# 17  VanderHouwen has more jobs you may like!  Find...
# 18  "Genesis10 is actively seeking a Messaging Adm...
# 19  Our client in the healthcare software industry...
#
#                                                 jobid  \
# 0                                  Dice Id : 10110693
# 1                                  Dice Id : 10114469
# 2                                  Dice Id : CXGALXYS
# 3                                  Dice Id : 10113627
# 4                                  Dice Id : matrixga
# 5                                  Dice Id : 10111847
# 6                                  Dice Id : 90884761
# 7                                  Dice Id : 10110132
# 8                                  Dice Id : gentx001
# 9                                   Dice Id : vhassoc
# 10                                 Dice Id : 10108942
# 11                                 Dice Id : 10106409
# 12                                  Dice Id : vhassoc
# 13                                 Dice Id : gentx001
# 14                                  Dice Id : vhassoc
# 15   QA & development environments.5+ years overal...
# 16                                Dice Id : 10208346J
# 17                                  Dice Id : vhassoc
# 18                 M/F/D/V""  Start Date: 06/08/2016"
# 19                                 Dice Id : 10111360
#
#                                   joblocation_address  \
# 0                                         Atlanta, GA
# 1                                         Chicago, IL
# 2                                      Schaumburg, IL
# 3                                     Bolingbrook, IL
# 4                                         Atlanta, GA
# 5                                         Chicago, IL
# 6                                         Atlanta, GA
# 7                                         Chicago, IL
# 8                                        New York, NY
# 9                                         Seattle, WA
# 10                                      Sunnyvale, CA
# 11                                Highlands Ranch, CO
# 12                                       Portland, OR
# 13                                    Los Angeles, CA
# 14                                      Hillsboro, OR
# 15   test and implementation of complex technical ...
# 16                                        Atlanta, GA
# 17                                      Beaverton, OR
# 18                                 Dice Id : gentx001
# 19                                         Denver, CO
#
#                                              jobtitle  \
# 0                            AUTOMATION TEST ENGINEER
# 1                       Information Security Engineer
# 2                        Business Solutions Architect
# 3   Java Developer (mid level)- FT- GREAT culture,...
# 4                                     DevOps Engineer
# 5                                  SAP FICO Architect
# 6                                    Network Engineer
# 7   Sr. Web Application Developer (Cloud Team) - C...
# 8                                 Front End Developer
# 9                        Application Support Engineer
# 10                         OpenStack Engineer - 12185
# 11      9001 Data Security Administrator - Unix & IAM
# 12                          Software Engineer Manager
# 13                        Sales Engineer - Los Angles
# 14                                    Project Manager
# 15               triaging as necessary for production
# 16                           Test Lead / Test Manager
# 17  Principal Application Analyst-Supply Chain Lawson
# 18                                    Kansas City, MO
# 19             Java Architect - Denver, CO - Fulltime
#
#                                              postdate  \
# 0                                          1 hour ago
# 1                                          1 week ago
# 2                                         2 weeks ago
# 3                                         2 weeks ago
# 4                                      48 minutes ago
# 5                                         2 weeks ago
# 6                                          1 hour ago
# 7                                         2 weeks ago
# 8                                         7 hours ago
# 9                                         7 hours ago
# 10                                        7 hours ago
# 11                                        7 hours ago
# 12                                        7 hours ago
# 13                                        7 hours ago
# 14                                        7 hours ago
# 15   QA & development environments.Work with exter...
# 16                                        7 hours ago
# 17                                        7 hours ago
# 18                            Messaging Administrator
# 19                                        7 hours ago
#
#                                                 shift  \
# 0     Telecommuting not available|Travel not required
# 1     Telecommuting not available|Travel not required
# 2     Telecommuting not available|Travel not required
# 3     Telecommuting not available|Travel not required
# 4     Telecommuting not available|Travel not required
# 5   Telecommuting not available|Travel required to...
# 6     Telecommuting not available|Travel not required
# 7     Telecommuting not available|Travel not required
# 8     Telecommuting not available|Travel not required
# 9     Telecommuting not available|Travel not required
# 10    Telecommuting not available|Travel not required
# 11    Telecommuting not available|Travel not required
# 12    Telecommuting not available|Travel not required
# 13    Telecommuting not available|Travel not required
# 14    Telecommuting not available|Travel not required
# 15   located in multiple datacentersExpert underst...
# 16        Telecommuting available|Travel not required
# 17    Telecommuting not available|Travel not required
# 18                                        7 hours ago
# 19    Telecommuting not available|Travel not required
#
#                                           site_name  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                              None
# 10                                             None
# 11                                             None
# 12                                             None
# 13                                             None
# 14                                             None
# 15           Active Directory & Domain architecture
# 16                                             None
# 17                                             None
# 18  Telecommuting not available|Travel not required
# 19                                             None
#
#                                                skills  \
# 0                                           SEE BELOW
# 1   linux/unix, network monitoring, incident respo...
# 2   Enterprise Solutions Architecture, business in...
# 3                          Please see job description
# 4   Configuration Management, Developer, Linux, Ma...
# 5                FICO, AR, AP, Asset Management, HAHA
# 6   Cisco, DNS, HTTP, Networking, Network Engineer...
# 7   .NET , C#, MVC, RESTful web services, HTTP, AW...
# 8   C++, Developer, Development, JavaScript, User ...
# 9                               (See Job Description)
# 10                                          Openstack
# 11  Unix, IAM, Scripting knowledge, OIM, Windows, ...
# 12                                          Java, OSS
# 13         Consulting, Project, Sales, Sales Engineer
# 14                                      mobile device
# 15                                   NTFS permissions
# 16                                                 QA
# 17                                Lawson Supply Chain
# 18                                               None
# 19                              (See Job Description)
#
#                                               uniq_id
# 0                    418ff92580b270ef4e7c14f0ddfc36b4
# 1                    8aec88cba08d53da65ab99cf20f6f9d9
# 2                    46baa1f69ac07779274bcd90b85d9a72
# 3                    3941b2f206ae0f900c4fba4ac0b18719
# 4                    45efa1f6bc65acc32bbbb953a1ed13b7
# 5                    e0ac9d926dda5e95162ef05adea7318c
# 6                    e7e326053c586bd94e59f1fd74de4a1b
# 7                    b0dadecf4c3c2beecb9c773ca11ecda4
# 8                    28f5e0c1cc3314813e674f0c32b04d1b
# 9                    95c9127e2770172f454f3b83981eaa88
# 10                   5e0ff38f5eaf44726f4e3d1dd257a244
# 11                   e4a1ff1b6c0fda5f345e57cf1acb40dd
# 12                   d0c81a2e3e5d666f3d730f1048c49132
# 13                   51279d060da242e3baea98b26ddd641e
# 14                   48b7ca0c2f6191fb48e7ecf19fbd3322
# 15                                               WINS
# 16                   e4dceaaaaae37ca6eabb04a7d42498b4
# 17                   7ad2eadde69e07fee0e38c1a251dd81f
# 18  Desktop, Hardware, Network, Software, Systems,...
# 19                   e4f57bc5366124a0a47cac27f557f9ec

# %% [markdown]
# ### Landing Jobs (API)
#
# Source: https://github.com/LandingJobs/LandingJobs-api

# %%
import requests as r
import pandas as pd

lj_jobs_offset = 0
lj_jobs_offset_interval = 50
lj_jobs_list = []

while lj_jobs_offset < 500:
    params = {'offset': lj_jobs_offset}
    response = r.get('https://landing.jobs/api/v1/jobs', params)
    lj_jobs_list.extend(response.json())
    lj_jobs_offset = lj_jobs_offset + lj_jobs_offset_interval


jobs_list_df = pd.DataFrame(lj_jobs_list)
jobs_list_df
# Out:
#        id    city  company_id country_code country_name currency_code  \
# 0    2579  Lisbon         256           PT     Portugal           EUR
# 1    2586  Lisbon         256           PT     Portugal           EUR
# 2    2587  Lisbon         256           PT     Portugal           EUR
# 3    3333  Lisbon         256           PT     Portugal           EUR
# 4    3335  Lisbon         256           PT     Portugal           EUR
# ..    ...     ...         ...          ...          ...           ...
# 423  8607   Braga         945           PT     Portugal           EUR
# 424  8608   Porto        3522           PT     Portugal           EUR
# 425  8609   Porto        3522           PT     Portugal           EUR
# 426  8613  Lisbon         358           PT     Portugal           EUR
# 427  8617  Berlin         147           DE      Germany           EUR
#
#      expires_at                                  main_requirements  \
# 0    2019-09-26  * Degree in Computer Science/IT or related fie...
# 1    2019-09-26  * Solid knowledge and minimum of 5 years’ expe...
# 2    2019-09-26  * Solid knowledge and a minimum of **3 years’ ...
# 3    2019-09-24  * Solid knowledge and minimum of **2 years’ ex...
# 4    2019-09-24  * Degree in Computer Science/IT or related fie...
# ..          ...                                                ...
# 423  2019-11-13  <ul><li>Experience in Project Management and F...
# 424  2020-02-04  <ul><li><!--block-->Bachelor's or higher techn...
# 425  2020-02-04  <ul><li><!--block-->Bachelor's or higher techn...
# 426  2019-11-14  <ul><li>5+ years experience in UX/UI<br></li><...
# 427  2019-11-14  <ul><li>You have at least 4 years of experienc...
#
#                                           nice_to_have  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 423
# 424  <ul><li><!--block-->Experience with financial,...
# 425  <ul><li><!--block-->Experience with financial,...
# 426  <ul><li><!--block-->Fluency in English<br></li...
# 427
#
#                                                  perks  ...  \
# 0    <p><strong>WHAT WE OFFER</strong></p><p>Beside...  ...
# 1    <p>Besides a competitive salary and a variable...  ...
# 2    * Besides a competitive salary and a variable ...  ...
# 3    <p>Besides a competitive salary and a variable...  ...
# 4    <p><strong>WHAT WE OFFER</strong></p><p>Beside...  ...
# ..                                                 ...  ...
# 423                                                     ...
# 424  <ul><li>Flexible schedules</li><li>Possibility...  ...
# 425  <ul><li>Flexible schedules</li><li>Possibility...  ...
# 426  <ul><li>A multidisciplinary team that values g...  ...
# 427  <ul><li>Relocation and visa support as well as...  ...
#
#                          title                created_at  \
# 0                  QA Engineer  2016-11-29T14:18:29.759Z
# 1    Full-stack Java Developer  2016-11-29T15:30:52.191Z
# 2      Java Back-end Developer  2016-11-29T15:34:54.817Z
# 3          Front-end Developer  2017-04-07T12:03:21.341Z
# 4     Junior Software Engineer  2017-04-07T12:09:35.897Z
# ..                         ...                       ...
# 423         Engagement Manager  2019-08-15T15:43:34.543Z
# 424          Android Developer  2019-08-15T18:41:34.305Z
# 425              iOS Developer  2019-08-15T18:50:46.233Z
# 426    Senior UX / UI Designer  2019-08-16T08:59:27.534Z
# 427        Senior Scrum Master  2019-08-16T12:46:32.820Z
#
#                    updated_at              published_at       type remote  \
# 0    2019-08-17T00:00:26.410Z  2016-11-29T16:11:43.398Z  Full-time  False
# 1    2019-08-17T00:00:37.740Z  2016-11-29T16:36:45.993Z  Full-time  False
# 2    2019-08-17T00:00:37.796Z  2017-06-19T09:16:27.968Z  Full-time  False
# 3    2019-08-17T00:00:30.785Z  2017-04-07T12:32:29.417Z  Full-time  False
# 4    2019-08-17T00:00:28.041Z  2017-04-07T12:28:05.147Z  Full-time  False
# ..                        ...                       ...        ...    ...
# 423  2019-08-17T00:00:38.665Z  2019-08-15T15:43:46.288Z  Full-time  False
# 424  2019-08-17T00:00:26.570Z  2019-08-16T08:12:38.145Z  Full-time  False
# 425  2019-08-17T00:00:29.742Z  2019-08-16T07:57:39.294Z  Full-time  False
# 426  2019-08-17T00:00:38.531Z  2019-08-16T09:31:21.393Z  Full-time  False
# 427  2019-08-17T00:00:34.262Z  2019-08-16T12:46:37.919Z  Full-time  False
#
#                                                   tags  \
# 0      [Continuous Delivery, Test Automation, Testing]
# 1                      [Hibernate, Java, JIRA, Spring]
# 2          [Apache Tomcat, Java, Jboss, MAVEN, Redhat]
# 3                 [AngularJS, MongoDB, Node.js, React]
# 4               [Java, JavaScript, MySQL, Spring, SQL]
# ..                                                 ...
# 423                       [Analyst, Projet Management]
# 424             [Android, Java, Mobile Developer, SQL]
# 425  [Cocoa, iOS, Mobile Applications, Objective-C,...
# 426  [Bohemian Coding Sketch, UX Design, Visual Com...
# 427   [Agile Coaching, Agile Metholody, Kanban, Scrum]
#
#                                                    url  gross_salary_low  \
# 0    https://landing.jobs/at/xpand-it/qa-engineer-i...               NaN
# 1    https://landing.jobs/at/xpand-it/full-stack-ja...               NaN
# 2    https://landing.jobs/at/xpand-it/java-back-end...               NaN
# 3    https://landing.jobs/at/xpand-it/front-end-dev...               NaN
# 4    https://landing.jobs/at/xpand-it/junior-softwa...               NaN
# ..                                                 ...               ...
# 423  https://landing.jobs/at/bizdirect/engagement-m...               NaN
# 424  https://landing.jobs/at/devexperts/android-dev...               NaN
# 425  https://landing.jobs/at/devexperts/ios-develop...               NaN
# 426  https://landing.jobs/at/by/senior-ux-ui-design...               NaN
# 427  https://landing.jobs/at/raisin/senior-scrum-ma...               NaN
#
#     gross_salary_high
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 423               NaN
# 424               NaN
# 425               NaN
# 426               NaN
# 427               NaN
#
# [428 rows x 23 columns]

# %%
response = r.get('https://landing.jobs/api/v1/companies')
lj_companies_list = response.json()
len(lj_companies_list)
# Out:
# 50

# %%
# APIs/Feeds to get:
# - https://stackoverflow.com/jobs/feed
# - https://jobs.github.com/api
# Two more ideas of sites to crawl:
# - https://relocate.me/
# - https://relocateme.eu/jobs/

# %% [markdown]
# ### Jobtechdev.se historical jobs
#
# Source: https://jobtechdev.se/api/jobs/historical/

# %%
import pandas as pd

def translate_jobtechdev_columns(df):
    return (
        df.withColumnRenamed('AG_NAMN', 'agency_name')
                   .withColumnRenamed('ANTAL_AKT_PLATSER', 'number_of_acting_sites')
                   .withColumnRenamed('ARBETSDRIFT', 'work_period')
                   .withColumnRenamed('ARBETSTID', 'working_hours')
                   .withColumnRenamed('BESKR_ARBETSDRIFT', 'working_hours_description')
                   .withColumnRenamed('FORSTA_PUBLICERINGSDATUM', 'published_at')
                   .withColumnRenamed('HEMSIDA', 'website')
                   .withColumnRenamed('KOMMUN_KOD', 'community_code')
                   .withColumnRenamed('ORGNR', 'company_number')
                   .withColumnRenamed('PLATSBESKRIVNING', 'job_description')
                   .withColumnRenamed('PLATSNUMMER', 'job_number')
                   .withColumnRenamed('PLATSRUBRIK', 'job_title')
                   .withColumnRenamed('POSTNR', 'zipcode')
                   .withColumnRenamed('POSTORT', 'city')
                   .withColumnRenamed('SISTA_ANSOK_PUBLDATUM', 'expires_at')
                   .withColumnRenamed('TILLTRADE', 'urgency_level_description')
                   .withColumnRenamed('VARAKTIGHET', 'duration')
    )

jtd_hist = 'datasets/jobtechdev-historical/2008.json'
jtd_hist_df = spark.read.json(jtd_hist)
jtd_hist_df = translate_jobtechdev_columns(jtd_hist_df)
jtd_hist_df.limit(100).toPandas()
# Out:
#    ADRESSLAND                                        agency_name  \
# 0        None                            Aktiebolaget Söder & Co
# 1        None                                  Ängelholms Kommun
# 2        None                               Omsorgsförvaltningen
# 3        None                                             Poolia
# 4        None  Järfälla kommun, Järfälla kommun, Barn- och un...
# ..        ...                                                ...
# 95       None                       GH  SERVICE GÖRAN HANSSON AB
# 96       None                                  Fastighetsservice
# 97       None                            Larssons Buss o Traktor
# 98       None                        Hays Specialist Rekrytering
# 99       None                AVIS BILUTHYRNING LIC./RIKSBILAR AB
#
#    number_of_acting_sites  work_period  working_hours  \
# 0                       1       Dagtid  Heltid/Deltid
# 1                      10       Dagtid  Heltid/Deltid
# 2                       1       Dagtid         Deltid
# 3                       1       Dagtid  Heltid/Deltid
# 4                       3       Dagtid  Heltid/Deltid
# ..                    ...          ...            ...
# 95                      1       Dagtid         Heltid
# 96                      1       Dagtid         Heltid
# 97                      0  Skiftarbete         Heltid
# 98                      1       Dagtid         Heltid
# 99                      1       Dagtid         Heltid
#
#                             working_hours_description published_at website  \
# 0                                                None   2008-01-28    None
# 1                               Säsongsanställning ()   2008-01-28    None
# 2       Visstidsanställning , Deltid 30 timmar/vecka.   2008-01-28    None
# 3                                              Heltid   2008-01-28    None
# 4                            Tillsvidare (enligt ök.)   2008-01-28    None
# ..                                                ...          ...     ...
# 95                                               None   2008-01-28    None
# 96  Heltid, tillsvidare Tillträdesdag snarast elle...   2008-01-28    None
# 97                                                tv.   2008-01-28    None
# 98                                               None   2008-01-28    None
# 99                                               None   2008-01-28    None
#
#    community_code company_number  \
# 0            1480           None
# 1            1292           None
# 2            1282           None
# 3            0180           None
# 4            0123           None
# ..            ...            ...
# 95           1482           None
# 96           1080           None
# 97           2523           None
# 98           2580           None
# 99           0184           None
#
#                                       job_description job_number  \
# 0   Aktiebolaget Söder och Co.verkar inom rekryter...       None
# 1   Ängelholms kommun är belägen i nordvästra Skån...       None
# 2   Omsorgsförvaltningen BESKRIVNING AV TJÄNSTEN S...       None
# 3   Poolia  PRESENTATION                          ...       None
# 4   Järfälla är en modern kommun med gamla anor, t...       None
# ..                                                ...        ...
# 95                          Vi söker en GRÄVMASKINIST       None
# 96  Telefoniavdelningen, som ingår i Landstinget B...       None
# 97                                       Maskinförare       None
# 98  Vi söker någon som kan sälja pumplösningar til...       None
# 99  **********************************************...       None
#
#                                           job_title zipcode        city  \
# 0                                  Förrådsman sökes    None    Göteborg
# 1             Semestervikarie Vårdare Gruppbostäder    None   Ängelholm
# 2   Hemvårdare/Vårdare  Semestervik Ref.nr 5100-004    None  Landskrona
# 3     Driven löneadministratör till företag i Solna    None   Stockholm
# 4                 Förskollärare till ANKA förskolor    None    Järfälla
# ..                                              ...     ...         ...
# 95                         Maskinförare GRÄVMASKINI    None        None
# 96                                     Teleingenjör    None  Karlskrona
# 97                                     Maskinförare    None        None
# 98                                          Säljare    None        None
# 99                                Marknadsassistent    None        None
#
#     expires_at urgency_level_description      duration YRKE_ID
# 0   2008-02-17                      None  Tills vidare    5843
# 1   2008-02-28                      None   3-6 månader    5797
# 2   2008-03-31                      None  Tills vidare    5799
# 3   2008-02-17                      None  Tills vidare    6025
# 4   2008-02-22                      None  Tills vidare    5714
# ..         ...                       ...           ...     ...
# 95  2008-02-27                      None  Tills vidare       0
# 96  2008-02-15                      None  Tills vidare       0
# 97  2008-01-29                  20080201  Tills vidare       0
# 98  2008-02-27                   Snarast  Tills vidare    5925
# 99  2008-02-15                   Snarast  Tills vidare    6314
#
# [100 rows x 19 columns]

# %%
import pandas as pd

jtd_hist = 'datasets/jobtechdev-historical/2013.json'
jtd_hist_df = spark.read.json(jtd_hist)
jtd_hist_df = translate_jobtechdev_columns(jtd_hist_df)
jtd_hist_df.limit(100).toPandas()
# Out:
#    ADRESSLAND                  agency_name number_of_acting_sites  \
# 0                    Örebro läns landsting                     14
# 1                               Dematek AB                      1
# 2                  Ageris Kontaktcenter AB                      9
# 3                     Silentium Contact AB                      5
# 4                    TEC Finance Sweden AB                      1
# ..        ...                          ...                    ...
# 95             Annedals Montessoriförskola                      1
# 96                       Oddwork Sweden AB                      2
# 97                            Care Team AB                      1
# 98                          Lux Svenska AB                      1
# 99                          Lux Svenska AB                      1
#
#              work_period  working_hours  \
# 0                 Dagtid         Heltid
# 1                 Dagtid         Heltid
# 2                 Dagtid         Heltid
# 3   Schemalagd arbetstid  Heltid/Deltid
# 4                 Dagtid         Heltid
# ..                   ...            ...
# 95                Dagtid         Heltid
# 96                Dagtid         Heltid
# 97                Dagtid         Heltid
# 98                Dagtid         Heltid
# 99                Dagtid         Heltid
#
#                             working_hours_description published_at  \
# 0                                                       2013-02-13
# 1                                                       2013-03-11
# 2                   Heltid/Deltid/Tillsvidare/Visstid   2013-04-02
# 3   Eftermiddag/kväll. Visstidsanställning med möj...   2013-04-18
# 4                                                       2013-05-21
# ..                                                ...          ...
# 95                                                      2013-01-08
# 96                                                      2013-01-08
# 97  Tjänsten startar omgående och löper tillsvidar...   2013-01-08
# 98                                                      2013-01-08
# 99                                                      2013-01-08
#
#    community_code                                    job_description  \
# 0            1883  Lednings- och verksamhetsstöd, LoVS, arbetar m...
# 1            0126  Du blir en del i vår Östra Serviceregion och f...
# 2            2313   Ageris Kontaktcenter AB levererar kundservice...
# 3            2582  Silentium arbetar med kundservice och försäljn...
# 4            0180  Vi söker en Ekonomi ansvarig/Ekonomi assistent...
# ..            ...                                                ...
# 95           0180  Vi söker en erfaren Förskollärare/Montessorilä...
# 96           1480  Vi söker entusiastiska och drivna norsktalande...
# 97           0180  Vill du jobba som arbetsterapeut med en konsul...
# 98           0126  Lux är ett av Sveriges mest anrika bolag och h...
# 99           0182  Lux är ett av Sveriges mest anrika bolag och h...
#
#                                        job_title       city  expires_at  \
# 0            Städare, semestervikariat Karlskoga       1883  2013-03-10
# 1                              Säljadministratör   HUDDINGE  2013-03-31
# 2                                Tid för avgång!      Solna  2013-04-21
# 3          Säljare/Kommunikatör semestervikariat             2013-05-12
# 4             Ekonomi ansvarig/Ekonomi assistent             2013-06-10
# ..                                           ...        ...         ...
# 95                Förskollärare/Montessorilärare  Stockholm  2013-02-07
# 96  Norsk säljare till nordiskt expansionsbolag!   Göteborg  2013-02-07
# 97                Care Team söker arbetsterapeut  STOCKHOLM  2013-02-07
# 98                    Blivande Gruppchef/Säljare   DANDERYD  2013-02-07
# 99                    Blivande Gruppchef/Säljare   DANDERYD  2013-02-07
#
#    urgency_level_description             duration YRKE_ID
# 0                                    Tills vidare     464
# 1                                    Tills vidare    4918
# 2                                    Tills vidare    2291
# 3     Enligt överenskommelse          3-6 månader    7468
# 4                                    Tills vidare    6024
# ..                       ...                  ...     ...
# 95                                   Tills vidare    5714
# 96                                   Tills vidare    2603
# 97                            Längre än 6 månader    5728
# 98                                   Tills vidare    3727
# 99                                   Tills vidare    3727
#
# [100 rows x 15 columns]

# %% [markdown]
# ### Monster.com jobs
#
# Source: https://www.kaggle.com/PromptCloudHQ/us-jobs-on-monstercom

# %%
monster_jobs = 'datasets/monster_com-job_sample.csv'
monster_jobs_df = spark.read.csv(monster_jobs, header=True)
monster_jobs_df.limit(100).toPandas()
# Out:
#                      country country_code date_added has_expired  \
# 0   United States of America           US       None          No
# 1   United States of America           US       None          No
# 2   United States of America           US       None          No
# 3   United States of America           US       None          No
# 4   United States of America           US       None          No
# ..                       ...          ...        ...         ...
# 95  United States of America           US       None          No
# 96  United States of America           US       None          No
# 97  United States of America           US       None          No
# 98  United States of America           US       None          No
# 99  United States of America           US       None          No
#
#            job_board                                    job_description  \
# 0   jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1   jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2   jobs.monster.com  "Report this job About the Job DePuy Synthes C...
# 3   jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4   jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
# ..               ...                                                ...
# 95  jobs.monster.com  The Judge Group is looking for a Scrum Master ...
# 96  jobs.monster.com  "Financial Advisor Northwestern MutualOur fina...
# 97  jobs.monster.com  Job Title: Personal Banker (SAFE) 1 - Bear Val...
# 98  jobs.monster.com  "*****THIS POSITION IS IN Decatur, IL. PLEASE ...
# 99  jobs.monster.com  MOUNTAIN, LTD. is currently seeking an OSP Fie...
#
#                                             job_title  \
# 0                IT Support Technician Job in Madison
# 1             Business Reporter/Editor Job in Madison
# 2   ""Images"":[{""Src"":""http://images.monster.c...
# 3                     Engineer - Quality Job in Dixon
# 4        Shift Supervisor - Part-Time Job in Camphill
# ..                                                ...
# 95                         Scrum Master Job in Denver
# 96                      we welcome your application."
# 97  Personal Banker (SAFE)  Bear Valley Job in Denver
# 98   please visit: http://www.volt.com and to see ...
# 99  Outside Plant Telecom Engineer () Job in Fort ...
#
#                                              job_type  \
# 0                                  Full Time Employee
# 1                                           Full Time
# 2                                      ""Title"":null
# 3                                           Full Time
# 4                                  Full Time Employee
# ..                                                ...
# 95                                Full Time, Employee
# 96  Financial Advisor / Financial Sales Representa...
# 97                                 Full Time Employee
# 98   please visit: http://jobs.volt.com •Send your...
# 99                                          Full Time
#
#                                              location  \
# 0                                   Madison, WI 53702
# 1                                   Madison, WI 53708
# 2                                       ""Text"":null
# 3                                           Dixon, CA
# 4                                        Camphill, PA
# ..                                                ...
# 95                                         Denver, CO
# 96                                 Full Time Employee
# 97                                         Denver, CO
# 98   IL. PLEASE APPLY ONLY IF YOU ARE INTERESTED F...
# 99                                   Fort Collins, CO
#
#                    organization  \
# 0                          None
# 1       Printing and Publishing
# 2             ""Caption"":null}
# 3              Altec Industries
# 4                        Retail
# ..                          ...
# 95         Computer/IT Services
# 96                  Houston, TX
# 97                      Banking
# 98   please go to www.volt.com"
# 99                         None
#
#                                              page_url  \
# 0   http://jobview.monster.com/it-support-technici...
# 1   http://jobview.monster.com/business-reporter-e...
# 2   {""Src"":""http://images.monster.com/mm/xjjson...
# 3   http://jobview.monster.com/engineer-quality-jo...
# 4   http://jobview.monster.com/shift-supervisor-pa...
# ..                                                ...
# 95  http://jobview.monster.com/Scrum-Master-Job-De...
# 96                                            Banking
# 97  http://jobview.monster.com/Personal-Banker-SAF...
# 98            Mechanical Engineer Relocate to Decatur
# 99  http://jobview.monster.com/Outside-Plant-Telec...
#
#                                                salary  \
# 0                                                None
# 1                                                None
# 2                                      ""Title"":null
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  http://jobview.monster.com/Financial-Advisor-F...
# 97                                               None
# 98                                 Full Time Employee
# 99                                               None
#
#                         sector                            uniq_id
# 0      IT/Software Development   11d599f229a80023d2f40e7c52cd941e
# 1                         None   e4cbb126dabf22159aff90223243ff2a
# 2                ""Text"":null                  ""Caption"":null}
# 3    Experienced (Non-Manager)   58435fcab804439efdcaa7ecca0fd783
# 4   Project/Program Management   64d0272dc8496abfd9523a8df63c184c
# ..                         ...                                ...
# 95     IT/Software Development   5091d726fbce4a824fe6a1d49458ad4a
# 96                        None  Sales/Retail/Business Development
# 97   Experienced (Non-Manager)   c639b20ed01b45b3f3aff1ef58a5d9ce
# 98             Bloomington, IL                               None
# 99                        None   fbabdfd6692540e30d7bccfe393adabe
#
# [100 rows x 14 columns]
